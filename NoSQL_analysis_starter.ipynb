# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}
result = establishments.find(query)

# Use count_documents to display the number of documents in the result
documents = establishments.count_documents(query)
print("Number of establishments with a hygiene score of 20:", documents)

# Display the first document in the results using pprint
pprint(db.establishments.find_one(query))
# Out:
# Number of establishments with a hygiene score of 20: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6498c31c55e5c27fdec45ab8'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
print(len(df))

# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6498c31c55e5c27fdec45ab8   110681                  0
# 1  6498c31c55e5c27fdec45e3a   612039                  0
# 2  6498c31c55e5c27fdec46145   730933                  0
# 3  6498c31c55e5c27fdec46332   172735                  0
# 4  6498c31c55e5c27fdec46340   172953                  0
# 5  6498c31d55e5c27fdec46cdd   512854                  0
# 6  6498c31d55e5c27fdec46f02  1537089                  0
# 7  6498c31d55e5c27fdec4842a   155648                  0
# 8  6498c31d55e5c27fdec48870  1012883                  0
# 9  6498c31d55e5c27fdec49094   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
# Use $regex in query line.
query = {"LocalAuthorityName": {'$regex':"London"},"RatingValue":{'$gte':4}}
results = establishments.find(query)

# Use count_documents to display the number of documents in the result
count_results = establishments.count_documents(query)
print("Number of establishments in London with a RatingValue greater than or equal to 4:", count_results)
     
# Display the first document in the results using pprint
pprint(results[0])
# Out:
# Number of establishments in London with a RatingValue greater than or equal to 4: 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6498c31d55e5c27fdec474d1'),
# ...

# %%
# Convert the result to a Pandas DataFrame
df_London_4 = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(len(df_London_4))

# Display the first 10 rows of the DataFrame
df_London_4.head(10)
# Out:
# 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  6498c31d55e5c27fdec474d1   621707                  0
# 1  6498c31d55e5c27fdec477fd  1130836                  0
# 2  6498c31d55e5c27fdec48347   293783                  0
# 3  6498c31d55e5c27fdec49145  1315095                  0
# 4  6498c31d55e5c27fdec49147   294474                  0
# 5  6498c31d55e5c27fdec49853   294900                  0
# 6  6498c31d55e5c27fdec4b95e   293756                  0
# 7  6498c31d55e5c27fdec4bd25   878523                  0
# 8  6498c31d55e5c27fdec4bd3f   293772                  0
# 9  6498c31d55e5c27fdec4bd40   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

# Query and find Lat. and Long. of "Penang Flavours" restaurant
query_1 = {'BusinessName': 'Penang Flavours'}
fields = {'geocode.latitude': 1, 'geocode.longitude': 1, '_id': 0}
results_1 = establishments.find_one(query_1, fields)

# Extract the Lat. and Long.
latitude = results_1['geocode']['latitude']
longitude = results_1['geocode']['longitude']

# Define the degree search range
degree_search = 0.01

# Define the query to find establishments with RatingValue of 5 within the search range.  Use greater than or equal to/less than or equal 
#to.  This should get search within the required 0.01 degree of either side.
query_2 = {
    'RatingValue': 5,
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search}
}

# Define the sort order by hygiene score
sort = [('scores.Hygiene', 1)]
limit = 5

results=list(establishments.find(query).sort(sort).limit(limit))

# Print the results
for result in results:
    
    pprint(result)
# Out:
# {'AddressLine1': 'Leslie Ford House',
#  'AddressLine2': 'Tilbury',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'BusinessName': 'Coombs Catering t/a The Lock and Key',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4636.846754121153,
#  'FHRSID': 1315095,
#  'LocalAuthorityBusinessID': 'PI/000036464',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM18 7EH',
#  'RatingDate': '2020-12-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6498c31d55e5c27fdec49145'),
#  'geocode': {'latitude': 51.4640655517578, 'longitude': 0.346336990594864},
# ...

# %%
# Convert result to Pandas DataFrame
df = pd.DataFrame(results)
print(df)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6498c31d55e5c27fdec49145  1315095                  0
# 1  6498c31d55e5c27fdec49147   294474                  0
# 2  6498c31d55e5c27fdec49853   294900                  0
# 3  6498c31d55e5c27fdec477fd  1130836                  0
# 4  6498c31d55e5c27fdec48347   293783                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000036464  Coombs Catering t/a The Lock and Key
# 1             PI/000014647              Tilbury Seafarers Centre
# 2             PI/000019066                            Mv Valulla
# 3             PI/000034075               Mv City Cruises Erasmus
# 4             PI/000002614             Benfleet Motor Yacht Club
#
#               BusinessType  BusinessTypeID  \
# 0  Restaurant/Cafe/Canteen               1
# 1  Restaurant/Cafe/Canteen               1
# 2  Other catering premises            7841
# 3  Other catering premises            7841
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
###(See 12 -  Folder 3 - Exercise 03 & 04 for reference)
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}}

# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}}

# 3. Sorts the matches from highest to lowest (descending order)
sort_values = {'$sort': { 'count': -1 }}

# Put the pipeline together
pipeline = [match_query, group_query, sort_values]

# Run the pipeline through the aggregate method and save the results to a variable
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of countries in result: ", len(results))
# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of countries in result:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
result_df.head(10)

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
